# %% [markdown]
# # Gráficos para dos variables cuantitativas

# %%
# Importar paquetes

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Students.csv") # Importar conjunto de datos

# Uso de graficos relacionales

sns.relplot(x="absences", y="G3", data=df, col="study_time") # Graficos relacionales para dos variables
plt.show()

# %%
# Es posible diferencialos por filas y columnsas de acuerdo a ciertos grupos o factores. Por ejemplo, para este caso
# se considera diferenciar si el desempeño de los estudiantes difiere cuando reciben apoyo por parte de su familia o extra

sns.relplot(x="G1", y="G2", data=df, col="famsup", col_order=["yes","no"], row="schoolsup", row_order=["yes","no"], height=4,
           aspect=1.5)
plt.show()

# %% [markdown]
# ## Personalización de gráficos de dispersión

# %%
df_2 = pd.read_csv("Automobile per gallon.csv")   # Importar un segundo conjunto de datos

# Es posible personalizar el tamaño de los puntos en fución del valor cuantitativo de la varible, igual que diferenciarlo por color
# Los argumentos height/aspect permiten modificar las dimensiones de los gráficos

sns.relplot(y="mpg", x="horsepower", data=df_2, kind="scatter", size="cylinders", hue="cylinders", height=5, aspect=1)
plt.show()

# %%
# Igualemnte es posible diferenciar los puntos como diferente figuras según una categoría

sns.relplot(y="mpg", x="horsepower", data=df_2, kind="scatter", hue="origin",
             style="origin", height=5, aspect=1)
plt.show()

# %% [markdown]
# ## Gráficos de líneas

# %%
df_2.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
# Se considera ahora la posibilidad de trazar líneas para la relación de dos variables

sns.relplot(x="model_year", y="mpg", data=df_2, kind="line")
plt.show()

# El área sombreada indica el intervalo de confianza para ese año

# %%
# En lugar del intervalo se puede especificar para que los limites estén dados por las desviaciones estándar

sns.relplot(x="model_year", y="mpg", data=df_2, kind="line",ci="sd")
plt.show()

# %%
# Al igual que en el diagrama de dispersión, existe la posibilidad de diferenciar las observaciones por categoría, en este caso,
# se toma por el estilo de las líneas

sns.relplot(x="model_year", y="horsepower", data=df_2, kind="line", style="origin", hue="origin",
            ci=None, dashes=False, markers=True)
plt.show()
